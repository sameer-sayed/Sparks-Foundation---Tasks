# %% [markdown]
# # Understanding how the DecisionTree Algorithm works with the help of "Iris" Dataset

# %%
#Importing the basic Libraries required
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import confusion_matrix

# %%
data = pd.read_csv('Iris.csv', index_col = 0)
data.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Seperating the independant features (x) and target output(y)
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
#Splitting the data fr training
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
#Creating a function that can later be used to input in DecisionTree model
def create_model(model):
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    print(classification_report(y_test,y_pred))
    return model

# %%
#creating an object of Decision Tree
dt=DecisionTreeClassifier()

# %%
#classification report of model dt
create_model(dt)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       0.94      0.94      0.94        18
#  Iris-virginica       0.92      0.92      0.92        13
#
#        accuracy                           0.96        45
#       macro avg       0.96      0.96      0.96        45
#    weighted avg       0.96      0.96      0.96        45
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
#Visualising the columns
features=x.columns
features
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
fig=plt.figure(figsize=(23,20))
_=tree.plot_tree(dt,feature_names=features,class_names=y.unique(),filled=True)

# %%
#Using ConfusionMatrix
plt.figure(figsize=(7,5))
sns.heatmap(confusion_matrix(y_test,y_pred), annot = True)

# %%
#This model can now predict any given data
